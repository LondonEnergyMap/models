# %%
import pandas as pd

epc_filepath = 'https://media.githubusercontent.com/media/LondonEnergyMap/cleandata/master/epc/domestic/epcdom_10meters.csv'
dfepc = pd.read_csv(epc_filepath)

dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas  nrooms  \
# 0  City of London      not recorded   48.30        Y       1
# 1  City of London  rental (private)   70.85        Y       3
# 2  City of London     marketed sale   66.00        Y       3
# 3  City of London     marketed sale   66.00        Y       3
# 4  City of London     marketed sale  111.00        Y       4
#
#                                               wall  gasmeters       gasmid  \
# 0                                             Wall        7.0  5636.993076
# 1  System built, as built, no insulation (assumed)        7.0  5636.993076
# 2   Solid brick, as built, no insulation (assumed)        7.0  5636.993076
# 3   Solid brick, as built, no insulation (assumed)        7.0  5636.993076
# 4   Solid brick, as built, no insulation (assumed)        7.0  5636.993076
#
#    elecmeters  elecmid
# 0         7.0   2874.8
# 1         7.0   2874.8
# 2         7.0   2874.8
# 3         7.0   2874.8
# 4         7.0   2874.8

# %%
# pcode1 = dfepc.pcode.iloc[0:9999]
# pcode2 = dfepc.pcode.iloc[10000:19999]
# pcode3 = dfepc.pcode.iloc[20000:29999]
# pcode4 = dfepc.pcode.iloc[30000:39999]
# pcode5 = dfepc.pcode.iloc[40000:49999]
# pcode6 = dfepc.pcode.iloc[50000:]

# %%
# pcode1.to_csv('pcode1.csv', index=False)
# pcode2.to_csv('pcode2.csv', index=False)
# pcode3.to_csv('pcode3.csv', index=False)
# pcode4.to_csv('pcode4.csv', index=False)
# pcode5.to_csv('pcode5.csv', index=False)
# pcode6.to_csv('pcode6.csv', index=False)

# %%
imd_filepath = 'https://media.githubusercontent.com/media/LondonEnergyMap/cleandata/master/epc/domestic/imd/ecp10meters_pcode_imd.csv'
dfimd = pd.read_csv(imd_filepath)
dfimd.head()
# Out:
#    Postcode Postcode Status  LSOA code                      LSOA Name  \
# 0  EC4Y 8DU            Live  E01032740  City of London 001G E01032740
# 1  EC4Y 8DU            Live  E01032740  City of London 001G E01032740
# 2  EC4Y 8DU            Live  E01032740  City of London 001G E01032740
# 3  EC4Y 8DU            Live  E01032740  City of London 001G E01032740
# 4  EC4Y 8DU            Live  E01032740  City of London 001G E01032740
#
#    Index of Multiple Deprivation Rank  Index of Multiple Deprivation Decile  \
# 0                               18868                                     6
# 1                               18868                                     6
# 2                               18868                                     6
# 3                               18868                                     6
# 4                               18868                                     6
#
#    Income Rank  Income Decile  Income Score  Employment Rank      ...       \
# 0        31643             10         0.029            31733      ...
# 1        31643             10         0.029            31733      ...
# 2        31643             10         0.029            31733      ...
# 3        31643             10         0.029            31733      ...
# 4        31643             10         0.029            31733      ...
#
#    Barriers to Housing and Services Rank  \
# 0                                   6063
# 1                                   6063
# 2                                   6063
# 3                                   6063
# 4                                   6063
#
#    Barriers to Housing and Services Decile  Living Environment Rank  \
# 0                                        2                       79
# 1                                        2                       79
# 2                                        2                       79
# 3                                        2                       79
# 4                                        2                       79
#
#    Living Environment Decile  IDACI Rank  IDACI Decile  IDACI Score  \
# 0                          1       32367            10        0.018
# 1                          1       32367            10        0.018
# 2                          1       32367            10        0.018
# 3                          1       32367            10        0.018
# 4                          1       32367            10        0.018
#
#    IDAOPI Rank  IDAOPI Decile  IDAOPI Score
# 0        32844             10         0.007
# 1        32844             10         0.007
# 2        32844             10         0.007
# 3        32844             10         0.007
# 4        32844             10         0.007
#
# [5 rows x 28 columns]

# %%
dfimd['Index of Multiple Deprivation Decile'].unique()
# Out:
# array([ 6,  7,  4,  2,  3,  1,  5,  9,  8, 10])

# %%
imd_dict = pd.Series(dfimd['Index of Multiple Deprivation Decile'].values, index=dfimd['Postcode']).to_dict()
imd_dict
# map postcode to deprivation index
dfepc['imd'] = dfepc.pcode.map(imd_dict)

# %%
# map nrooms=-1 to nroom based on floor area bands similar to NEED
import numpy as np

areabins = [0, 50, 100, 150, 200]
arealabels = [1, 2, 3, 4]

dfepc['nroomtfa'] = pd.cut(dfepc.tfa, areabins, labels=arealabels) 

dfepc['nroom'] = np.where(dfepc.nrooms==-1, dfepc.nroomtfa, dfepc.nrooms) 
dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas  ...    \
# 0  City of London      not recorded   48.30        Y  ...
# 1  City of London  rental (private)   70.85        Y  ...
# 2  City of London     marketed sale   66.00        Y  ...
# 3  City of London     marketed sale   66.00        Y  ...
# 4  City of London     marketed sale  111.00        Y  ...
#
#                                               wall gasmeters       gasmid  \
# 0                                             Wall       7.0  5636.993076
# 1  System built, as built, no insulation (assumed)       7.0  5636.993076
# 2   Solid brick, as built, no insulation (assumed)       7.0  5636.993076
# 3   Solid brick, as built, no insulation (assumed)       7.0  5636.993076
# 4   Solid brick, as built, no insulation (assumed)       7.0  5636.993076
#
#    elecmeters  elecmid  imd  nroomtfa nroomstfa2  nrooms2  nroom
# 0         7.0   2874.8    6         1        1.0      1.0    1.0
# 1         7.0   2874.8    6         2        3.0      3.0    3.0
# 2         7.0   2874.8    6         2        3.0      3.0    3.0
# 3         7.0   2874.8    6         2        3.0      3.0    3.0
# 4         7.0   2874.8    6         3        4.0      4.0    4.0
#
# [5 rows x 21 columns]

# %%
# convert property type and form to exposed sides

# create new column for number of exposed sides based on property type and form
prop_mapping = {'House': 0, 'Flat': -2, 'Bungalow': 0.5, 'Maisonette': -2,
                'Park home': 0}
built_mapping = {'Detached': 0, 'Semi-Detached': -1,
                 'End-Terrace': -1, 'Mid-Terrace': -2,
                 'Enclosed Mid-Terrace': -2.5, 'Enclosed End-Terrace': -1.5,
                 'NO DATA!': 0}

dfepc['propmap'] = dfepc.prop_type.map(prop_mapping)
dfepc['builtmap'] = dfepc.builtform.map(built_mapping)
dfepc['exposedsides'] = 6 + dfepc.propmap + dfepc.builtmap

dfepc['type'] = dfepc.prop_type.str.lower()
dfepc['form'] = dfepc.builtform.str.lower()

dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas          ...           \
# 0  City of London      not recorded   48.30        Y          ...
# 1  City of London  rental (private)   70.85        Y          ...
# 2  City of London     marketed sale   66.00        Y          ...
# 3  City of London     marketed sale   66.00        Y          ...
# 4  City of London     marketed sale  111.00        Y          ...
#
#    imd nroomtfa  nroomstfa2  nrooms2  nroom  propmap  builtmap exposedsides  \
# 0    6        1         1.0      1.0    1.0     -2.0       0.0          4.0
# 1    6        2         3.0      3.0    3.0     -2.0      -2.0          2.0
# 2    6        2         3.0      3.0    3.0     -2.0      -2.0          2.0
# 3    6        2         3.0      3.0    3.0     -2.0      -2.0          2.0
# 4    6        3         4.0      4.0    4.0     -2.0      -2.5          1.5
#
#    type                  form
# 0  flat              detached
# 1  flat           mid-terrace
# 2  flat           mid-terrace
# 3  flat           mid-terrace
# 4  flat  enclosed mid-terrace
#
# [5 rows x 26 columns]

# %%
# convert wall and transaction type to building age

# create new column of building age based on wall description and transcation type
dfepc['wall_firstword'] = dfepc.wall.str.split().str.get(0)
wall_mapping = {'Cavity': 2, 'System': 3, 'Timber': 3}
dfepc['age'] = dfepc.wall_firstword.map(wall_mapping)
dfepc.age.fillna(1, inplace=True)
dfepc.loc[dfepc.transact_type == 'new dwelling', 'age'] = 6

dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas ...   nroomstfa2 nrooms2  \
# 0  City of London      not recorded   48.30        Y ...          1.0     1.0
# 1  City of London  rental (private)   70.85        Y ...          3.0     3.0
# 2  City of London     marketed sale   66.00        Y ...          3.0     3.0
# 3  City of London     marketed sale   66.00        Y ...          3.0     3.0
# 4  City of London     marketed sale  111.00        Y ...          4.0     4.0
#
#    nroom  propmap  builtmap  exposedsides  type                  form  \
# 0    1.0     -2.0       0.0           4.0  flat              detached
# 1    3.0     -2.0      -2.0           2.0  flat           mid-terrace
# 2    3.0     -2.0      -2.0           2.0  flat           mid-terrace
# 3    3.0     -2.0      -2.0           2.0  flat           mid-terrace
# 4    4.0     -2.0      -2.5           1.5  flat  enclosed mid-terrace
#
#    wall_firstword  age
# 0            Wall  1.0
# 1          System  3.0
# 2           Solid  1.0
# 3           Solid  1.0
# 4           Solid  1.0
#
# [5 rows x 28 columns]

# %%
mains_dict = {'Y': 1, 'N': 0}
dfepc['maingas'] = dfepc.mainsgas.map(mains_dict)
dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas   ...     nrooms2 nroom  \
# 0  City of London      not recorded   48.30        Y   ...         1.0   1.0
# 1  City of London  rental (private)   70.85        Y   ...         3.0   3.0
# 2  City of London     marketed sale   66.00        Y   ...         3.0   3.0
# 3  City of London     marketed sale   66.00        Y   ...         3.0   3.0
# 4  City of London     marketed sale  111.00        Y   ...         4.0   4.0
#
#    propmap  builtmap  exposedsides  type                  form wall_firstword  \
# 0     -2.0       0.0           4.0  flat              detached           Wall
# 1     -2.0      -2.0           2.0  flat           mid-terrace         System
# 2     -2.0      -2.0           2.0  flat           mid-terrace          Solid
# 3     -2.0      -2.0           2.0  flat           mid-terrace          Solid
# 4     -2.0      -2.5           1.5  flat  enclosed mid-terrace          Solid
#
#    age  maingas
# 0  1.0      1.0
# 1  3.0      1.0
# 2  1.0      1.0
# 3  1.0      1.0
# 4  1.0      1.0
#
# [5 rows x 29 columns]

# %%
epc_dict = {'A': 1, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6}
dfepc['epc_band'] = dfepc.curr_enr.map(epc_dict)
dfepc.head()
# Out:
#       pcode        bref curr_enr  curr_encons prop_type             builtform  \
# 0  EC4Y 8DU  3221499468        C         9662      Flat              Detached
# 1  EC4Y 8DU  2290543668        C          172      Flat           Mid-Terrace
# 2  EC4Y 8DU  6015699968        C          146      Flat           Mid-Terrace
# 3  EC4Y 8DU  9939448868        C          139      Flat           Mid-Terrace
# 4  EC4Y 8DU  1536490868        C          154      Flat  Enclosed Mid-Terrace
#
#                la     transact_type     tfa mainsgas    ...     nroom propmap  \
# 0  City of London      not recorded   48.30        Y    ...       1.0    -2.0
# 1  City of London  rental (private)   70.85        Y    ...       3.0    -2.0
# 2  City of London     marketed sale   66.00        Y    ...       3.0    -2.0
# 3  City of London     marketed sale   66.00        Y    ...       3.0    -2.0
# 4  City of London     marketed sale  111.00        Y    ...       4.0    -2.0
#
#    builtmap  exposedsides  type                  form  wall_firstword  age  \
# 0       0.0           4.0  flat              detached            Wall  1.0
# 1      -2.0           2.0  flat           mid-terrace          System  3.0
# 2      -2.0           2.0  flat           mid-terrace           Solid  1.0
# 3      -2.0           2.0  flat           mid-terrace           Solid  1.0
# 4      -2.5           1.5  flat  enclosed mid-terrace           Solid  1.0
#
#    maingas  epc_band
# 0      1.0         2
# 1      1.0         2
# 2      1.0         2
# 3      1.0         2
# 4      1.0         2
#
# [5 rows x 30 columns]

# %%
epc_cols = ['bref', 
             'imd', 
             'type', 
             'form', 
             'exposedsides', 
             'tfa', 
             'epc_band', 
             'age', 
             'nroom', 
             'maingas', 
             'gasmid', 
             'elecmid',
             'gasmeters',
             'elecmeters']

dfepc = dfepc[epc_cols]
dfepc.head()
# Out:
#          bref  imd  type                  form  exposedsides     tfa  \
# 0  3221499468    6  flat              detached           4.0   48.30
# 1  2290543668    6  flat           mid-terrace           2.0   70.85
# 2  6015699968    6  flat           mid-terrace           2.0   66.00
# 3  9939448868    6  flat           mid-terrace           2.0   66.00
# 4  1536490868    6  flat  enclosed mid-terrace           1.5  111.00
#
#    epc_band  age  nroom  maingas       gasmid  elecmid  gasmeters  elecmeters
# 0         2  1.0    1.0      1.0  5636.993076   2874.8        7.0         7.0
# 1         2  3.0    3.0      1.0  5636.993076   2874.8        7.0         7.0
# 2         2  1.0    3.0      1.0  5636.993076   2874.8        7.0         7.0
# 3         2  1.0    3.0      1.0  5636.993076   2874.8        7.0         7.0
# 4         2  1.0    4.0      1.0  5636.993076   2874.8        7.0         7.0

# %%
rename_cols = ['hid', 
             'imd', 
             'type', 
             'form', 
             'exposedsides', 
             'tfa', 
             'epc', 
             'age', 
             'nroom', 
             'maingas', 
             'gcons', 
             'econs',
             'gmeters',
             'emeters']
dfepc.columns = rename_cols
